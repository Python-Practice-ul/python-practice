# %%
x =101
y =1234567890987654321

# %%
print(x)
print(y)
# Out:
# 101
# 1234567890987654321

# %%
import sys
sys.getsizeof(x)
# Out:
# 28

# %%
import sys
sys.getsizeof(y)
# Out:
# 36

# %% [markdown]
# # complex

# %%
c = 10+5j
print(type(c))
# Out:
# <class 'complex'>

# %%
c
# Out:
# (10+5j)

# %%
c = complex(5,3.1)
print(c)
# Out:
# (5+3.1j)

# %%
c = complex(10)
c
# Out:
# (10+0j)

# %%
x = 101
print(id(x))
# Out:
# 1713696560624

# %%
x = 205
print(id(x))
# Out:
# 1713696564016

# %% [markdown]
# # literals
# Integer
# float
# boolean
# complex
# string

# %%
x = 3
y = 564_7_89_123
print(x)
print(y)
# Out:
# 3
# 564789123

# %%
x = _5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 x = _5
#
# NameError: name '_5' is not defined

# %%
x=5_
# Out:
#   Input In [11]
#     x=5_
#        ^
# SyntaxError: invalid decimal literal

# %%
#float

# %%
a = 9.75
b = 3.43
print(a,b)
# Out:
# 9.75 3.43

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
c = 12E3
d = 12.5E-2
print(c,d)
# Out:
# 12000.0 0.125

# %%
print(type(d))
# Out:
# <class 'float'>

# %%
#base conversions

# %%
s1 = bin(10)
s2 = oct(10) 
s3 = hex(10)
print(s1,s2,s3)
# Out:
# 0b1010 0o12 0xa

# %%
type(s3)
# Out:
# str

# %%
f = 16.59
b = True
s1 = '125'
s2 = '0b1010'
s3 = '0xA'

# %%
x = int(f)
print(x,type(x))
# Out:
# 16 <class 'int'>

# %%
int(b)
# Out:
# 1

# %%
int(s1)
# Out:
# 125

# %%
x-int(s2,2)
print(x,type(x))
# Out:
# 16 <class 'int'>

# %%
#float

# %%
i=125
b=True
s='12.75'

# %%
x = float(i)
print(x,type(x))
# Out:
# 125.0 <class 'float'>

# %%
z = float(b)
print(z,type(z))
# Out:
# 1.0 <class 'float'>

# %%
a = float(s)
print(a,type(a))
# Out:
# 12.75 <class 'float'>

# %%
# bool

# %%
i2 = 20
a = 300

# %%
x = bool(i2)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
x = bool(a)
print(x,type(x))
# Out:
# True <class 'bool'>

# %%
bool(False)
# Out:
# False

# %%
# Complex

# %%
i = 10
f = -12.5
b1 = True
b2 = False
s = '3+4j'

# %%
k = complex(i)
print(k,type(k))
# Out:
# (10+0j) <class 'complex'>

# %%
complex(f)
# Out:
# (-12.5+0j)

# %%
complex(b1)
# Out:
# (1+0j)

# %%
complex(b2)
# Out:
# 0j

# %%
complex(s)
# Out:
# (3+4j)

# %%
# string

# %%
i1 = 10
i2 = -12
f = -1.2E3
b1 = False
c = 3+4j

# %%
x = str(i1)
print(x,type(x))
# Out:
# 10 <class 'str'>

# %%
str(i2)
# Out:
# '-12'

# %%
str(f)
# Out:
# '-1200.0'

# %%
str(b1)
# Out:
# 'False'

# %%
str(c)
# Out:
# '(3+4j)'

# %%
a=20
x=oct(a)
x
# Out:
# '0o24'

# %%
length = 15
breadth = 5
area = length * breadth 
print('Area :', area)
# Out:
# Area : 75

# %%
# Given the Length of the Rectangle
length = 15 

# Given the breadth of the Rectangle
breadth = 5 


# Complete the formula, the Area of a Rectangle in the line below. 



area = length * breadth



# Display the area of a Rectangle.
print('Area is', area)
# Out:
# Area is 75

# %%
length = int(input("enter  length"))
breadth = int(input("enter  breadth"))
area = length * breadth
print("Area :" ,area)
# Out:
# enter  length5
# enter  breadth5
# Area : 25

# %%
import math

r = 10

#Complete the formula for the area of the circle in  below line.

area = math.pi * r * r

print("Area is : ", area)
# Out:
# Area is :  314.1592653589793

# %%
kilometers = 15

# Write down the kilometers to miles conversion in the below line

miles = 0.621371*kilometers

print('Miles =', miles)
# Out:
# Miles = 9.320565

# %%
u = 4
v = 6
a = 3

#Comple the next line.

d = (v*v-u*u)/(2*a)

print("Displacement is : ", d)
# Out:
# Displacement is :  3.3333333333333335

# %%
l = 10
b = 5
h = 7
area = 2*(l*h + l*b + b*h)
print(area)
# Out:
# 310

# %%
l = int(input('enter a number'))
b = int(input('enter a number'))
h = int(input('enter a number'))
area = 2*(l*h + l*b + b*h)
print(area)
# Out:
# enter a number5
# enter a number10
# enter a number15
# 550

# %%
import math

a = int(input('enter root number'))
b = int(input('enter root number'))
c = int(input('enter root number'))
r1 = (-b + math.sqrt(b ** 2 - 4 * a * c)) / (2 * a)
r2 = (-b - math.sqrt(b ** 2 - 4 * a * c)) / (2 * a)

print('Roots are',r1,r2)
# Out:
# enter root number3
# enter root number10
# enter root number7
# Roots are -1.0 -2.3333333333333335

# %%
#arithmetic Assingment

# %%
a = 6
b = 3
a+=b
print(a)
# Out:
# 9

# %%
a = 6
b = 3
a-=b
print(a)
# Out:
# 3

# %%
a = 6
b = 3
a/=b
print(a)
# Out:
# 2.0

# %%
a = 6
b = 3
c=2
x=10
x+=(a*b-c)
print(a)
# Out:
# 6

# %%
# String

# %%
a = '1234'
b = '567'
print(a+b)
# Out:
# 1234567

# %%
a = 'vicky'
print(a*4)
# Out:
# vickyvickyvickyvicky
